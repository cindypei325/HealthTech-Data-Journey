# %%
# 1. 載入Pandas
import pandas as pd

# 2. 建立一份微型的臨床醫療數據 (Dictionary 格式)
mock_clinical_data = {
    'Patient_ID': ['P-001', 'P-002', 'P-003', 'P-004'],
    'Age': [26, 45, 60, 32],
    'Blood_Glucose': [90, 105, 140, 95],
    'Heart_Rate': [72, 80, 85, 76]
}

# 3. 將數據轉換成結構化的 DataFrame (資料表)
df = pd.DataFrame(mock_clinical_data)

# 4. 印出成功訊息與前幾筆資料
print("任務完成：成功建立並載入結構化醫療數據！")
df.head()
# Out:
# 任務完成：成功建立並載入結構化醫療數據！
#   Patient_ID  Age  Blood_Glucose  Heart_Rate
# 0      P-001   26             90          72
# 1      P-002   45            105          80
# 2      P-003   60            140          85
# 3      P-004   32             95          76

# %%
# 今日Mission：建立結構化醫療數據 (Structured Data)

## 核心概念：為什麼數據分析的第一步是 DataFrame？
## 要讓機器學習模型發揮作用，第一步必須將資料轉換成二維的「結構化矩陣」

### 本次實作目標
### 今天我們模擬一個微型的 EMR (電子病歷) 數據流：
### 1. Raw Data 模擬：將散落的病患指標（年齡、血糖、心率）收集進一個 Python Dictionary 中。
### 2. Data Structuring：** 使用 `pd.DataFrame()` 將其轉換為標準的數據表格式。
